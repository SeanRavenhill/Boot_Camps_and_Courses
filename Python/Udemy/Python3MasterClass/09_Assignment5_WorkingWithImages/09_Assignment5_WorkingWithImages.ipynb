# %% [markdown]
# # Blue Mission Overview
#
# Looks like the email reply had two links:
#
# https://drive.google.com/file/d/15YyLqIuGlsCLr4ioKUeHRw8H2QjBNOz2/view
#
# https://drive.google.com/file/d/128MRLNuytoW7dVm6B7AF_cDVMeACyTFk/view
#
# See if you can figure out how to use these images to figure out the next step.
#
# Best of luck!

# %%
from PIL import Image

# %%
links = Image.open('image_link.PNG')

# %%
links.size
# Out:
# (1226, 777)

# %%
links
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1226x777 at 0x7FA90D631670>

# %%
cover = Image.open('cover_image.PNG')

# %%
cover.size
# Out:
# (1093, 693)

# %%
cover
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1093x693 at 0x7FA90D631580>

# %%
cover = cover.resize(links.size)

# %%
cover.size
# Out:
# (1226, 777)

# %%
cover.putalpha(200)

# %%
cover
# Out:
# <PIL.Image.Image image mode=RGBA size=1226x777 at 0x7FA90D5DACD0>

# %%
links.paste(cover,(0,0),cover)

# %%
links
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1226x777 at 0x7FA90D631670>

# %% [markdown]
# https://goo.gl/LDo5Nt
